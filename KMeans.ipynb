# %%
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_iris
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
kMeansModel = KMeans(n_clusters=3)
kMeansModel.fit(X)
yPred = np.choose(kMeansModel.labels_,[0,1,2]).astype(np.int64)

# %%
scaler = StandardScaler()
scaler.fit(X)
xsa = scaler.transform(X)
xs = pd.DataFrame(xsa, columns=X.columns)
gmm = GaussianMixture(n_components=3)
gmm.fit(xs)
yPredCluster = gmm.predict(xs)

# %%
colorMap = np.array(['red', 'lime', 'teal'])
plt.figure(figsize=[14, 7])
plt.subplot(1, 3, 1)
plt.scatter(X.Petal_Length, X.Petal_Width, c=colorMap[Y.Targets])
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.title('Real Cluster')
plt.subplot(1, 3, 2)
plt.scatter(X.Petal_Length, X.Petal_Width, c=colorMap[yPred])
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.title('KMeans Cluster')
plt.subplot(1, 3, 3)
plt.scatter(X.Petal_Length, X.Petal_Width, c=colorMap[yPredCluster])
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.title('GMM Cluster')
# Out:
# Text(0.5, 1.0, 'GMM Cluster')
